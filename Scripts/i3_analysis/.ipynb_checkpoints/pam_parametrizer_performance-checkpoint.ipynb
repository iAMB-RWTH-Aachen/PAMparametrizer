# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# Get the current working directory
current_directory = os.getcwd()
# If required go to repository root
if os.path.split(current_directory)[1] != 'PAM_Parametrization':
    # Go up two levels
    parent_directory = os.path.dirname(os.path.dirname(current_directory))
    # Change the directory to the parent directory
    os.chdir(parent_directory)
    
from Scripts.i2_parametrization.pam_parametrizer_performance_analysis import get_statistics_from_df
# Out:
# Loading PAModelpy modules version 0.0.4.7
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-03-03

# %% [markdown]
# ## Get the model diagnostics

# %%
NUM_ALT_MODELS=8
DIAGNOSTIC_FILES = [os.path.join('Results','2_parametrization', 'diagnostics',
                                 f'pam_parametrizer_diagnostics_{file_nmbr}.xlsx')for file_nmbr in range(1,NUM_ALT_MODELS+1)]

# %%
best_individual_df = None

for i, file in enumerate(DIAGNOSTIC_FILES):
    pam_param_results = pd.read_excel(file, sheet_name = 'Best_Individuals')
    pam_param_error = pd.read_excel(file, sheet_name='Final_Errors')
    pam_param_results = pam_param_results.merge(pam_param_error, on='run_id', how='left')
    pam_param_results['alternative'] = i+1
    
    if best_individual_df is None: 
        best_individual_df = pam_param_results
    else:
        best_individual_df = pd.concat([best_individual_df,pam_param_results])
best_individual_df
# Out:
#         run_id             enzyme_id direction                       rxn_id  \
# 0            1  P06959_P0A9P0_P0AFG8         f  CE_PDH_P06959_P0A9P0_P0AFG8
# 1            1  P06959_P0A9P0_P0AFG8         b  CE_PDH_P06959_P0A9P0_P0AFG8
# 2            1                P0A6P9         f                CE_ENO_P0A6P9
# 3            1                P0A6P9         b                CE_ENO_P0A6P9
# 4            1                P0A799         f                CE_PGK_P0A799
# ...        ...                   ...       ...                          ...
# 491331      10                Q93K97         f             CE_ADPRDP_Q93K97
# 491332      10                Q93K97         f             CE_ADPRDP_Q93K97
# 491333      10                Q93K97         f             CE_ADPRDP_Q93K97
# 491334      10                Q93K97         f             CE_ADPRDP_Q93K97
# 491335      10                Q93K97         f             CE_ADPRDP_Q93K97
#
#           kcat[s-1]  ga_error  r_squared  alternative
# 0        216.433957 -2.929269  -3.636335            1
# 1       2146.457212 -2.929269  -3.636335            1
# 2        134.426238 -2.929269  -3.636335            1
# 3         10.722444 -2.929269  -3.636335            1
# 4       1063.779018 -2.929269  -3.636335            1
# ...             ...       ...        ...          ...
# 491331  2489.708594  0.630984  -2.499378            8
# 491332  2489.708594  0.630984  -2.200479            8
# 491333  2489.708594  0.630984  -0.646287            8
# 491334  2489.708594  0.630984   0.471508            8
# 491335  2489.708594  0.630984  -0.275785            8
#
# [1459312 rows x 8 columns]

# %%
error_per_runid_config = get_statistics_from_df(best_individual_df,
                                                            group_by = ['run_id'],
                                                            columns = ['ga_error', 'r_squared'])
error_per_runid_config
# Out:
#    run_id  ga_error_mean  ga_error_median  ga_error_std  ga_error_min  \
# 0       1      -3.044587        -2.929269      0.552745     -3.733721
# 1       2      -2.160890        -2.066526      0.775559     -3.512433
# 2       3      -1.089357        -1.008272      0.671038     -2.030003
# 3       4      -0.604776        -0.613537      0.618811     -1.472569
# 4       5      -0.559280        -0.612049      0.580308     -1.449176
# 5       6       0.479859         0.548881      0.287667     -1.162591
# 6       7       0.435679         0.556712      0.176796     -0.761476
# 7       8       0.494314         0.556985      0.187091     -0.335051
# 8       9       0.494811         0.556990      0.182438     -0.288134
# 9      10       0.495539         0.557503      0.181943     -0.269707
#
#    ga_error_max  r_squared_mean  r_squared_median  r_squared_std  \
# 0     -2.073715       -3.754516         -3.636335       0.990401
# 1     -0.983499       -3.309888         -2.342251       1.351911
# 2      0.170548       -2.288483         -2.194711       1.096075
# 3      0.526962       -2.599485         -2.178668       1.529466
# 4      0.552742       -2.394231         -2.144710       1.232377
# 5      0.562142       -2.414908         -2.207529       1.586727
# 6      0.628355       -2.024573         -2.027692       1.528731
# 7      0.763597       -1.665510         -2.141997       1.228714
# 8      0.831683       -1.461606         -1.157065       1.216246
# 9      0.832007       -1.450441         -1.149999       1.204164
#
#    r_squared_min  r_squared_max
# 0      -4.829301      -1.936992
# 1      -5.518606      -1.929692
# 2      -4.604660      -1.022978
# 3      -5.382911      -0.435019
# 4      -4.400812      -0.341564
# 5      -4.365992      -0.285489
# 6      -4.473881      -0.251681
# 7      -3.402329       0.375461
# 8      -3.281317       0.470875
# 9      -3.226000       0.471508

# %% [markdown]
# ## Plot distribution

# %%
#plot histogram
bins =100

plt.hist(best_individual_df.drop_duplicates(['alternative', 'run_id']).r_squared, 
         bins= bins, label = 'parametrizer')
plt.xlabel('$R^{2}$ of simulations')
plt.ylabel('number of runs')
plt.legend()

# %% [markdown]
# ## Plot evaluation of error during runs

# %% [markdown]
# ## PAMparametrizer errors

# %%
iteration = best_individual_df.drop(
    [col for col in best_individual_df.columns if col not in ['alternative', 'run_id', 'r_squared']], 
    axis=1).drop_duplicates(['alternative', 'run_id'], keep ='first').groupby('alternative')
fig, ax = plt.subplots()
for name, group in iteration:
    ax.plot(group['run_id'], group['r_squared'], label=name)
ax.set_xlabel('run id within iteration')
ax.set_ylabel('$R^{2}$')
plt.legend(loc = 'right')
plt.show()

# %%
fig, ax = plt.subplots()
iteration = best_individual_df.drop(
    [col for col in best_individual_df.columns if col not in ['alternative', 'run_id', 'r_squared']], 
    axis=1).drop_duplicates(['alternative', 'run_id'], keep ='last').groupby('alternative')
for name, group in iteration:
    ax.plot(group['run_id'], group['r_squared'], label=f"Alternative {name}", linestyle='dashed', alpha=0.5)
ax.scatter(error_per_runid_config['run_id'], error_per_runid_config['r_squared_mean'], color='black', label='mean')
ax.errorbar(error_per_runid_config['run_id'], error_per_runid_config['r_squared_mean'],
            yerr = error_per_runid_config['r_squared_std'], color ='black',label = 'Mean')
ax.set_xlabel('run id within alternative')
ax.set_ylabel('Mean $R^{2}$ from PAMparametrizer ')
plt.show()

# %% [markdown]
# ## Genetic Algorithm errors

# %%
iteration = best_individual_df.drop(
    [col for col in best_individual_df.columns if col not in ['alternative', 'run_id', 'ga_error']], 
    axis=1).drop_duplicates(['alternative', 'run_id'], keep ='last').groupby('alternative')
fig, ax = plt.subplots()
for name, group in iteration:
    ax.plot(group['run_id'], group['ga_error'], label=f"Alternative {name}", linestyle='dashed', alpha=0.5)

ax.scatter(error_per_runid_config['run_id'], error_per_runid_config['ga_error_mean'], color='black')
ax.errorbar(error_per_runid_config['run_id'], error_per_runid_config['ga_error_mean'],
            yerr = error_per_runid_config['ga_error_std'], label='Mean', color='black')
ax.set_xlabel('run id within iteration')
ax.set_ylabel('Mean $R^{2}$ from genetic algorithm')
plt.legend(loc = 'right')
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(error_per_runid_config['run_id'], error_per_runid_config['ga_error_mean'])
ax.errorbar(error_per_runid_config['run_id'], error_per_runid_config['ga_error_mean'],
            yerr = error_per_runid_config['ga_error_std'])
ax.set_xlabel('run id within alternative')
ax.set_ylabel('Mean $R^{2}$ from genetic algorithm')
plt.show()

# %% [markdown]
# # Parameter estimation for translational protein sector
# This notebook was used to estimate the parameters for the translational protein sector as used in the revised proteome allocation model. This notebook has been created to establish the parameters for *Saccharomyces cerevisiae* CEN.PK-117D. The initial parameters were already established by [Pranas Grigaitis](https://pranasag.github.io/) in [Elsemman et al (2021)](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8831649/) (caption in Figure S10, suplementary text S2.3).
#
# **Author: Samira L. van den Bogaard**
#
# ### Setting up the notebook environment

# %%
#package
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

if os.path.split(os.getcwd())[1] == 'Yeast9':
    os.chdir('../../..')
    
from PAModelpy import Config

from Scripts.pam_generation_uniprot_id import set_up_ecoli_pam as setup_yeast_pam
from Scripts.pam_generation_uniprot_id import set_up_yeast_config

from Modules.utils.sector_config_functions import (perform_linear_regression,
                                                                        reset_translational_sector,
                                                                        plot_translational_protein_vs_mu,
                                                                        get_model_simulations_vs_sector,
                                                  )
# Out:
# Loading PAModelpy modules version 0.0.3.15
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-03-06

# %%
#constants
#files and file paths
DATA_FILE_PATH = os.path.join('Data', 'Scerevisiae_phenotypes', 'Proteome',
                              'Elsemman2021_quant_proteomics_scerevisiaecenpk.xls')
FUNCTIONAL_ANNOTATION_FILE_PATH =os.path.join('Data', 'Scerevisiae_phenotypes', 'Proteome',
                                              'TableS1_elsemman-etal2021_functional-annotation.xls')
PAM_DATA_FILE_PATH = os.path.join('Data', 'proteinAllocationModel_yeast9_EnzymaticData_240903.xlsx')
VALID_DATA_FILE_PATH = os.path.join('Data', 'Ecoli_phenotypes', 'Scerevisiae_phenotypes.xlsx')
RESULT_FIG_PATH = os.path.join('Figures', 'SuppFig1_translational_sector_Scerevisiae.png')

#data parsing
PROTEIN_FRACTION_AE_UE = 0.6809 #[g_prot/g_prot] as published in Elsemman et al (2021) Table S7
PROTEIN_FRACTION_0 = 0.3888 #[g_prot/g_cdw] as published in Elsemman et al (2021) Table S1
PROTEIN_FRACTION_MU = 0.4854 #[g_prot/g_cdw/h] as published in Elsemman et al (2021) Table S1

MEASURED_PROTEIN_FRACTION = 1#not mentioned in Elsemman et al 2021 
#0.55*0.55#0.55 * 0.55 #measured proteome vs g_p/gcdw in Ecoli
GLC_UPTAKE_RXN_ID = 'r_1714'
BIOMASS_RXN_ID = 'r_2111'
MW_GLC = 180.15588 #g/mol

# %% [markdown]
# ### Configure parameters and data
# To establish the relation between translational protein and substrate uptake rate we use the relation between translational protein and growth rate from the data from [Elsemman et al (2021)](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8831649/). For that we set up the model with the sector constraints by [Alter et al. (2021)](https://journals.asm.org/doi/10.1128/mSystems.00625-20) and let it run without total protein constraint. This way we obtain a relationship between the translational protein and substrate uptake rate: the translational protein sector is determined by the relation to growth as published by [Elsemman et al (2021)](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8831649/) and the substrate uptake rate corresponding to the specific growth rate are predicted by the model. Because the relationship between growth and translational protein might cease when the *S. cerevisiae* cells are entering overflow metabolism, we do not use the datapoints in the dataset from [Elsemman et al (2021)](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8831649/) which belong to growth rates in the overflow regime.

# %%
#set up model without total protein constraint to just model the linear relation between
config = Config()
config.

pamodel = setup_yeast_pam(pam_info_file = PAM_DATA_FILE_PATH, model = 'yeast9.xml'
                          total_protein=False, active_enzymes = False, unused_enzymes = False,
                          sensitivity = False) # sensitivity disabled to speed things up
#get parameters
translational_sector = pamodel.sectors.get_by_id('TranslationalProteinSector')
tps_molmass = translational_sector.mol_mass[0]
# Out:
# Setting up the proteome allocation model iML1515
#
# Total condition-dependent protein constraint is not added
#
# Add the following protein sector: TranslationalProteinSector
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_244345/2038945320.py in <module>
#       1 #set up model without total protein constraint to just model the linear relation between
# ----> 2 pamodel = setup_yeast_pam(pam_info_file = PAM_DATA_FILE_PATH,
#       3                           total_protein=False, active_enzymes = False, unused_enzymes = False,
#       4                           sensitivity = False) # sensitivity disabled to speed things up
#       5 #get parameters
#
# ~/Documents/3_Projects/9_PAM_parametrization/PAM_Parametrization/Scripts/pam_generation_uniprot_id.py in set_up_ecoli_pam(pam_info_file, model, config, total_protein, active_enzymes, translational_enzymes, unused_enzymes, sensitivity)
#     169     if total_protein: total_protein = TOTAL_PROTEIN_CONCENTRATION
#     170
# --> 171     pamodel = PAModel(id_or_model=model, p_tot=total_protein,
#     172                        active_sector=active_enzyme_sector, translational_sector=translation_enzyme_sector,
#     173                        unused_sector=unused_protein_sector, sensitivity=sensitivity, configuration = config
#
# ~/.local/lib/python3.10/site-packages/PAModelpy/PAModel.py in __init__(self, id_or_model, name, p_tot, sensitivity, active_sector, translational_sector, unused_sector, custom_sectors, configuration)
#     130         for sector in [sector for sector in sectors_to_add if sector is not None]:
#     131             if sector is not None:
# --> 132                 self.add_sectors([sector])
#     133         print(f"Done with setting up the proteome allocation model {self.id}\n")
#     134
#
# ~/.local/lib/python3.10/site-packages/PAModelpy/PAModel.py in add_sectors(self, sectors)
#     473                 self = sector.add(self)
#     474             else:
# --> 475                 self.add_sector(sector)
#     476
#     477     def add_sector(self, sector):
#
# ~/.local/lib/python3.10/site-packages/PAModelpy/PAModel.py in add_sector(self, sector)
#     487         sector.model = self
#     488
# --> 489         lin_rxn = self.reactions.get_by_id(sector.id_list[0])
#     490
#     491         # relate the sector to the total protein if it is there
#
# ~/.local/lib/python3.10/site-packages/cobra/core/dictlist.py in get_by_id(self, id)
#      71     def get_by_id(self, id: Union[Object, str]) -> Object:
#      72         """Return the element with a matching id."""
# ---> 73         return list.__getitem__(self, self._dict[id])
#      74
#      75     def list_attr(self, attribute: str) -> list:
#
# KeyError: 'r_2111'

# %%
#get the validation data
df_schmidt = pd.read_excel(DATA_FILE_PATH)
#removing conditions which we do not want to include in the analysis
for condition in NOT_IN_ANALYSIS_LIST:
    df_schmidt = df_schmidt[df_schmidt['Medium'] != condition]
    
#filter the range of growth rates for those who are nor influenced by more complex metabolic processes, such as:
#stationary growth
df_schmidt_nozero = df_schmidt[df_schmidt['Experimental Growth rate']>0.1]
#overflow metabolism
df_schmidt_nozero = df_schmidt_nozero[(df_schmidt_nozero['Experimental Growth rate']<0.4) | (df_schmidt_nozero['Experimental Growth rate']>0.7)]

# %% [markdown]
# The slope and intercept are derived from proteome measurements. We know these measurement are related to a total protein concentration of 0.32 g/g_cdw. This is why we need to correct the slope and intercept when it it incorporated into the model.

# %%
#get the relation with growth rate
slope, intercept = perform_linear_regression(x=df_schmidt_nozero['Experimental Growth rate'], y=df_schmidt_nozero['Translation, ribosomal structure and biogenesis']/100*MEASURED_PROTEIN_FRACTION/PROTEIN_FRACTION)

print('Translational sector vs growth rate using data from Schmidt et al (2016): \n Intercept: ',intercept*MEASURED_PROTEIN_FRACTION, 'g/g_cdw')
print('Slope: ',slope*MEASURED_PROTEIN_FRACTION, 'g/g_cdw/h')
# Out:
# Translational sector vs growth rate using data from Schmidt et al (2016):
#  Intercept:  0.04738115630907698 g/g_cdw
# Slope:  0.04806975534478209 g/g_cdw/h

# %% [markdown]
# ### Use the mu vs translational protein relationship to perform simulations with the PAM model
# The predicted glucose uptake rates can be used to derive the relationship between glucose uptake and translational protein.

# %%
#adjust relation in model
trans_sector = pamodel.sectors.get_by_id('TranslationalProteinSector')

#adjust the translational protein sector
pamodel.change_sector_parameters(trans_sector, slope*MEASURED_PROTEIN_FRACTION,
                                 intercept*MEASURED_PROTEIN_FRACTION, lin_rxn_id = BIOMASS_RXN_ID)

# %%
#run the model
substrate_range = np.arange(-11,1,1)

#we shouldn't correct for measured total protein here, as we are comparing it to the measured data
simulation_results_bms = get_model_simulations_vs_sector(pamodel, GLC_UPTAKE_RXN_ID, BIOMASS_RXN_ID,
                                           substrate_range, intercept,slope)
# Out:
# Running simulations with  -11 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -10 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -9 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -8 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -7 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -6 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -5 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -4 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -3 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -2 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -1 mmol/g_cdw/h of substrate going into the system
# Running simulations with  0 mmol/g_cdw/h of substrate going into the system
# /home/samiralvdb/.local/lib/python3.10/site-packages/cobra/util/solver.py:554: UserWarning:
#
# Solver status is 'infeasible'.

# %%
#derive the relation to glucose uptake rate
#results are in g_transprot/g_prot and need to be converted to g/gcdw (glucose uptake should stay in mmol for compatibility with model)
slope_glc, intercept_glc = perform_linear_regression(
    x=simulation_results_bms[GLC_UPTAKE_RXN_ID], y=simulation_results_bms['translational_protein'])

print('Translational sector vs glucose uptake using data from Schmidt et al (2016): \n Intercept: ',intercept_glc *MEASURED_PROTEIN_FRACTION, ' g/g_cdw')
print('Slope: ',slope_glc*MEASURED_PROTEIN_FRACTION, ' g/mmol_glucose/h')
# Out:
# Translational sector vs glucose uptake using data from Schmidt et al (2016):
#  Intercept:  0.046136644909661156  g/g_cdw
# Slope:  -0.004340256958025944  g/mmol_glucose/h

# %%
#visualization of results
plot_translational_protein_vs_mu(df_schmidt, simulation_results_bms, 
                                 protein_fraction = PROTEIN_FRACTION, 
                                 measured_protein_fraction=MEASURED_PROTEIN_FRACTION,
                                 oxygen_results = None)

# %% [markdown]
# ### Use the glucose vs translational protein relationship to perform simulations with the PAM model with only the translational protein sector
#
# The result will be compared to the experimental data. The slope and intercept are derived from proteome measurements. We know these measurement are related to a total protein concentration of 0.32 g/g_cdw. This is why we need to correct the slope and intercept when it it incorporated into the model. In the comparison, this correction is not required.

# %%
#make a model with only translational protein sector
pamodel_transl = setup_ecoli_pam(total_protein=False, active_enzymes = False, unused_enzymes = False,
                          sensitivity = False) # sensitivity disabled to speed things up

#adjust the translational protein sector
# pamodel_transl = reset_translational_sector(pamodel_transl, slope_glc*MEASURED_PROTEIN_FRACTION, 
#                                             intercept_glc*MEASURED_PROTEIN_FRACTION, new_id = GLC_UPTAKE_RXN_ID)
trans_sector = pamodel_transl.sectors.get_by_id('TranslationalProteinSector')

pamodel_transl.change_sector_parameters(trans_sector, slope_glc*MEASURED_PROTEIN_FRACTION,
                                 intercept_glc*MEASURED_PROTEIN_FRACTION, 
                                        lin_rxn_id = GLC_UPTAKE_RXN_ID)
# Out:
# Setting up the proteome allocation model iML1515
#
# Total condition-dependent protein constraint is not added
#
# Add the following protein sector: TranslationalProteinSector
#
# Done with setting up the proteome allocation model iML1515

# %%
simulation_results_glc = get_model_simulations_vs_sector(pamodel_transl, GLC_UPTAKE_RXN_ID, GLC_UPTAKE_RXN_ID,
                                           substrate_range, intercept_glc, slope_glc, to_save = BIOMASS_RXN_ID)
# Out:
# Running simulations with  -11 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -10 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -9 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -8 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -7 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -6 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -5 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -4 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -3 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -2 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -1 mmol/g_cdw/h of substrate going into the system
# Running simulations with  0 mmol/g_cdw/h of substrate going into the system
# /home/samiralvdb/.local/lib/python3.10/site-packages/cobra/util/solver.py:554: UserWarning:
#
# Solver status is 'infeasible'.

# %%
#visualize results
plot_translational_protein_vs_mu(df_schmidt, simulation_results_glc,
                                 protein_fraction = PROTEIN_FRACTION, 
                                 measured_protein_fraction=MEASURED_PROTEIN_FRACTION,
                                 oxygen_results = None)

# %% [markdown]
# ### Full PAM simulations (all sectors)
# Now let's see if we can improve the fit through the datapoints from [Schmidt et al. (2016)](https://www.nature.com/articles/nbt.3418) if we use the newly obtained relationship in a PAM with all protein sectors.

# %%
#make a model with only translational protein sector
pamodel_full = setup_ecoli_pam_old(pam_data_file_path = os.path.join('Data', 
                                                            'proteinAllocationModel_iML1515_EnzymaticData_py.xls'),
                                   unused_enzymes = False,
                                   sensitivity = False) # sensitivity disabled to speed things up

trans_sector = pamodel_full.sectors.get_by_id('TranslationalProteinSector')

#adjust the translational protein sector
pamodel_full.change_sector_parameters(trans_sector, slope_glc*MEASURED_PROTEIN_FRACTION, 
                                      intercept_glc*MEASURED_PROTEIN_FRACTION, 
                                      lin_rxn_id = GLC_UPTAKE_RXN_ID,
                                    print_change=True)
# Out:
# Setting up the proteome allocation model iML1515
#
# Add total condition-dependent protein constraint
# 	Total protein concentration: 0.258 g/gDW
#
# Add active protein sector
# /home/samiralvdb/.local/lib/python3.10/site-packages/PAModelpy/PAModel.py:230: UserWarning:
#
# Molar mass for E332 is invalid: 0.0
# Add the following protein sector: TranslationalProteinSector
#
# Done with setting up the proteome allocation model iML1515
#
# Changing the slope and intercept of the TranslationalProteinSector
# Changing slope from 36.8 to -4.340256958025944 mg/gcdw/h
# Changing intercept from 49.92 to 46.13664490966116 mg/gcdw

# %%
simulation_results = get_model_simulations_vs_sector(pamodel_full, GLC_UPTAKE_RXN_ID, GLC_UPTAKE_RXN_ID, 
                                           substrate_range, intercept_glc, slope_glc, to_save =BIOMASS_RXN_ID,)

# # Also add the linear relation to growth rate to compare with the linear relation with glucose uptake
# slope, intercept = perform_linear_regression(simulation_results[BIOMASS_RXN_ID],
#                                                                 simulation_results['translational_protein'])

# #add extrapolation of results for complex growth medium (1.9 h-1)
# row = simulation_results.iloc[-1]
# row[BIOMASS_RXN_ID] = 1.9
# row['translational_protein'] = (intercept + slope*1.9)
# simulation_results.loc[len(simulation_results.index)] = row.to_list()
# Out:
# Running simulations with  -11 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -10 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -9 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -8 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -7 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -6 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -5 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -4 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -3 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -2 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -1 mmol/g_cdw/h of substrate going into the system
# Running simulations with  0 mmol/g_cdw/h of substrate going into the system
# /home/samiralvdb/.local/lib/python3.10/site-packages/cobra/util/solver.py:554: UserWarning:
#
# Solver status is 'infeasible'.

# %%
#visualize results
fig_to_save, ax = plot_translational_protein_vs_mu(df_schmidt, simulation_results,
                                 protein_fraction = PROTEIN_FRACTION, 
                                 measured_protein_fraction=MEASURED_PROTEIN_FRACTION,
                                 oxygen_results = None, return_fig=True)

ax.plot(simulation_results_bms[BIOMASS_RXN_ID], simulation_results_bms['translational_protein'],
                 linestyle='dashed', color = 'black', linewidth=5, zorder=5, 
       label = 'previous iML1515 PAM')

ax.set_xlim([-0.01,1])
ax.legend()
plt.savefig(RESULT_FIG_PATH)

# %% [markdown]
# ### Oxygen limitation simulations
# By limiting the amount of oxygen, the organism will switch to a fermentative phenotype. As a consequence, more protein space for translational protein is freed. This mimmics the effect of overflow metabolism on the amount of translational protein (this can be seen in the data).

# %%
#run the simulations for different oxygen availabilities
o2_simulations = pd.DataFrame(columns = list(simulation_results.columns) + ['o2'])
for o2_level in OXYGEN_GRADIENT:
    print(f'\nRun model with {o2_level} mmol/g_cdw/h of oxygen going into the system')
    pamodel_transl.change_reaction_bounds('EX_o2_e', lower_bound = -o2_level, upper_bound = o2_level)
    simulation_results_o2 = get_model_simulations_vs_sector(pamodel_transl, GLC_UPTAKE_RXN_ID, GLC_UPTAKE_RXN_ID,
                                           substrate_range, intercept, slope, to_save = BIOMASS_RXN_ID)
    simulation_results_o2['o2'] = o2_level
    
    o2_simulations = pd.concat([o2_simulations, simulation_results_o2])
# Out:
# Run model with 5 mmol/g_cdw/h of oxygen going into the system
# Running simulations with  -11 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -10 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -9 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -8 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -7 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -6 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -5 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -4 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -3 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -2 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -1 mmol/g_cdw/h of substrate going into the system
# Running simulations with  0 mmol/g_cdw/h of substrate going into the system
#
# Run model with 10 mmol/g_cdw/h of oxygen going into the system
# Running simulations with  -11 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -10 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -9 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -8 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -7 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -6 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -5 mmol/g_cdw/h of substrate going into the system
# /home/samiralvdb/.local/lib/python3.10/site-packages/cobra/util/solver.py:554: UserWarning:
#
# Solver status is 'infeasible'.
# Running simulations with  -4 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -3 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -2 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -1 mmol/g_cdw/h of substrate going into the system
# Running simulations with  0 mmol/g_cdw/h of substrate going into the system
#
# Run model with 15 mmol/g_cdw/h of oxygen going into the system
# Running simulations with  -11 mmol/g_cdw/h of substrate going into the system
# /home/samiralvdb/.local/lib/python3.10/site-packages/cobra/util/solver.py:554: UserWarning:
#
# Solver status is 'infeasible'.
# Running simulations with  -10 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -9 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -8 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -7 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -6 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -5 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -4 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -3 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -2 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -1 mmol/g_cdw/h of substrate going into the system
# Running simulations with  0 mmol/g_cdw/h of substrate going into the system
# /home/samiralvdb/.local/lib/python3.10/site-packages/cobra/util/solver.py:554: UserWarning:
#
# Solver status is 'infeasible'.
# Run model with 17 mmol/g_cdw/h of oxygen going into the system
# Running simulations with  -11 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -10 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -9 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -8 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -7 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -6 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -5 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -4 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -3 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -2 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -1 mmol/g_cdw/h of substrate going into the system
# Running simulations with  0 mmol/g_cdw/h of substrate going into the system
#
# Run model with 20 mmol/g_cdw/h of oxygen going into the system
# Running simulations with  -11 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -10 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -9 mmol/g_cdw/h of substrate going into the system
# /home/samiralvdb/.local/lib/python3.10/site-packages/cobra/util/solver.py:554: UserWarning:
#
# Solver status is 'infeasible'.
# Running simulations with  -8 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -7 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -6 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -5 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -4 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -3 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -2 mmol/g_cdw/h of substrate going into the system
# Running simulations with  -1 mmol/g_cdw/h of substrate going into the system
# Running simulations with  0 mmol/g_cdw/h of substrate going into the system
# /home/samiralvdb/.local/lib/python3.10/site-packages/cobra/util/solver.py:554: UserWarning:
#
# Solver status is 'infeasible'.

# %% [markdown]
# ### Plot the results

# %%
# Also add the linear relation to growth rate to compare with the linear relation with glucose uptake
slope, intercept = perform_linear_regression(simulation_results[BIOMASS_RXN_ID],
                                                                simulation_results['translational_protein'])

#add extrapolation of results for complex growth medium (1.9 h-1)
row = o2_simulations.iloc[-1]
row[BIOMASS_RXN_ID] = 1.9
row['translational_protein'] = (intercept + slope*1.9)
o2_simulations.loc[len(o2_simulations.index)] = row.to_list()
# Out:
# /tmp/ipykernel_95825/316433851.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_95825/316433851.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#plotting vs mu
plot_translational_protein_vs_mu(df_schmidt, simulation_results, 
                                 protein_fraction = PROTEIN_FRACTION, 
                                 measured_protein_fraction=MEASURED_PROTEIN_FRACTION, 
                                 oxygen_results = o2_simulations, oxygen_rxn_id = 'o2')
